# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'anarchism', 'term', 'as', 'term', 'originated', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.058945
# Nearest to war: vertebrates, symphonie, welwyn, infinitesimals, pipelined, hohmann, muay, aural,
# Nearest to only: commodore, ris, albino, walls, gregers, accordion, hose, ifn,
# Nearest to by: compendium, evangelism, roda, displays, diocesan, athelstan, shuffling, fingerprints,
# Nearest to on: cauldron, ivies, skaldic, archbishopric, remarkable, aldiss, titan, beacons,
# Nearest to that: evenings, benhavn, reverted, interim, respiratory, hayt, shula, hanse,
# Nearest to were: mina, expressways, beechcraft, commissioner, desktops, garc, impoverishment, interviewed,
# Nearest to and: trondheim, fuses, precedes, brisbane, bestiary, rolland, lighters, gonzo,
# Nearest to are: inflow, shipped, guam, heifer, mafiosi, debuts, cultured, escort,
# Nearest to most: fanbase, jensen, commandment, prejudicial, fausto, commas, tel, mount,
# Nearest to eight: optically, obtain, hume, loyalty, electroconvulsive, taoist, outages, psychometrics,
# Nearest to often: cain, scapegoat, nairobi, electress, antibiotics, functioning, kislev, logik,
# Nearest to to: senna, comprehended, solaris, jump, atlantans, nk, rockstar, deprogrammers,
# Nearest to as: misskelley, rx, chewed, teacher, varies, ghazi, saguinus, implicit,
# Nearest to s: moons, hypotension, father, halakhah, verdeans, anger, satyr, hurd,
# Nearest to people: bathroom, unwin, increase, sokal, battering, sicilies, documentaries, mathematicians,
# Nearest to not: nato, westport, andros, boredom, standards, milhaud, ordovician, distributes,
# Average loss at step 2000: 4.335997
# Average loss at step 4000: 3.917822
# Average loss at step 6000: 3.758320
# Average loss at step 8000: 3.759029
# Average loss at step 10000: 3.663102
# Nearest to war: ayer, welwyn, vertebrates, pipelined, symphonie, muay, infinitesimals, remade,
# Nearest to only: commodore, similar, apocalypse, brooding, ciliates, erick, carolinas, blurring,
# Nearest to by: was, be, with, compendium, as, were, and, bashir,
# Nearest to on: in, from, for, at, through, hajj, bibliographical, polynesia,
# Nearest to that: which, freelance, fawkes, this, ellipsoid, deserters, sopra, but,
# Nearest to were: are, was, expressways, by, baldwin, cti, be, jagiello,
# Nearest to and: or, but, of, from, s, with, in, who,
# Nearest to are: were, is, be, was, and, have, lenihan, booking,
# Nearest to most: fanbase, voigt, knife, possessed, polynomials, copa, eyeball, intersects,
# Nearest to eight: seven, nine, five, four, six, zero, three, one,
# Nearest to often: also, functioning, nairobi, electress, kislev, there, fathom, cain,
# Nearest to to: for, would, with, not, and, nk, bout, from,
# Nearest to as: in, into, massive, by, maneuvers, agitated, jussive, planck,
# Nearest to s: and, the, nizam, anger, monomers, infusion, quadratic, angelic,
# Nearest to people: designs, bathroom, unwin, battering, anemometers, stars, increase, nationwide,
# Nearest to not: it, still, boredom, andros, to, walras, nato, abandoning,
# Average loss at step 12000: 3.654389
# Average loss at step 14000: 3.404495
# Average loss at step 16000: 3.608741
# Average loss at step 18000: 3.534291
# Average loss at step 20000: 3.562333
# Nearest to war: ayer, pipelined, welwyn, vertebrates, symphonie, remade, muay, dymaxion,
# Nearest to only: not, erick, pheasants, incarceration, clauses, blurring, spratly, until,
# Nearest to by: be, sampras, with, golem, been, from, was, as,
# Nearest to on: in, at, from, through, finish, during, skaldic, against,
# Nearest to that: which, this, it, but, shula, because, however, what,
# Nearest to were: are, was, have, had, been, is, be, kelvins,
# Nearest to and: or, but, assaults, celt, pickard, ginette, of, with,
# Nearest to are: were, is, have, be, juggling, lenihan, aggravated, for,
# Nearest to most: more, voigt, direct, fanbase, heil, intersects, possessed, knife,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to often: also, usually, which, sometimes, generally, nairobi, there, functioning,
# Nearest to to: will, nk, must, rejoining, would, unloaded, beretta, permission,
# Nearest to as: maneuvers, casta, is, though, by, leveled, planck, ltv,
# Nearest to s: his, situs, subsonic, anger, grouse, chloroplast, iberia, leni,
# Nearest to people: designs, revolution, stars, encyclopedic, sidi, anemometers, slander, forms,
# Nearest to not: still, it, boredom, they, usually, nato, only, there,
# Average loss at step 22000: 3.537479
# Average loss at step 24000: 3.486292
# Average loss at step 26000: 3.460258
# Average loss at step 28000: 3.479501
# Average loss at step 30000: 3.479465
# Nearest to war: ayer, pipelined, welwyn, symphonie, vertebrates, poignant, tanistry, larp,
# Nearest to only: until, erick, acquittal, within, spratly, mutant, not, nemesis,
# Nearest to by: with, and, be, was, clutter, shuffling, after, mahesh,
# Nearest to on: in, through, upon, at, from, bushnell, isopropyl, coupon,
# Nearest to that: which, this, however, but, because, what, amharic, gera,
# Nearest to were: are, was, have, had, internalism, and, be, been,
# Nearest to and: by, s, or, but, were, who, besiege, in,
# Nearest to are: were, is, have, be, juggling, internalism, can, chassis,
# Nearest to most: more, many, some, pupil, yf, voigt, heil, geology,
# Nearest to eight: nine, six, seven, four, five, three, zero, one,
# Nearest to often: usually, sometimes, generally, commonly, also, widely, still, nairobi,
# Nearest to to: will, would, nk, rejoining, diplomas, sprang, can, must,
# Nearest to as: teacher, completeness, massive, karelian, maneuvers, in, guelfs, warplanes,
# Nearest to s: and, monomers, his, bill, aeronautics, chloroplast, ansible, tente,
# Nearest to people: designs, others, those, encyclopedic, revolution, sauces, documentaries, buddhist,
# Nearest to not: still, they, usually, boredom, we, walras, clausewitz, abandoning,
# Average loss at step 32000: 3.520385
# Average loss at step 34000: 3.472660
# Average loss at step 36000: 3.498675
# Average loss at step 38000: 3.407040
# Average loss at step 40000: 3.162194
# Nearest to war: ayer, welwyn, muay, pipelined, vertebrates, poignant, infinitesimals, colombo,
# Nearest to only: spratly, moa, not, until, ruled, augsburg, but, mutant,
# Nearest to by: was, through, mahesh, until, bashir, naka, under, from,
# Nearest to on: through, upon, in, at, from, adware, around, under,
# Nearest to that: which, however, this, what, it, gera, but, there,
# Nearest to were: are, was, have, been, be, internalism, had, canteen,
# Nearest to and: or, but, especially, pickard, totals, ifs, levelling, which,
# Nearest to are: were, is, have, be, although, include, formality, these,
# Nearest to most: more, many, some, pupil, nage, fanbase, tilting, heil,
# Nearest to eight: six, five, seven, four, nine, three, zero, two,
# Nearest to often: usually, sometimes, generally, commonly, also, there, now, still,
# Nearest to to: rejoining, through, from, would, towards, will, against, transnistria,
# Nearest to as: karelian, became, received, massive, cortez, keel, maneuvers, without,
# Nearest to s: missions, monomers, goncourt, infusion, tente, exhibiting, ansible, schechter,
# Nearest to people: others, revolution, men, cort, those, karlheinz, designs, tabernacle,
# Nearest to not: still, they, usually, boredom, walras, only, andros, now,
# Average loss at step 42000: 3.490385
# Average loss at step 44000: 3.420342
# Average loss at step 46000: 3.423287
# Average loss at step 48000: 3.456827
# Average loss at step 50000: 3.415982
# Nearest to war: welwyn, wars, muay, pipelined, ayer, dymaxion, poignant, vertebrates,
# Nearest to only: spratly, theodora, moa, first, until, easily, acquittal, not,
# Nearest to by: through, when, with, being, was, guatemalan, suckling, during,
# Nearest to on: upon, through, at, thessalonica, against, hajj, in, vaux,
# Nearest to that: which, however, shula, because, what, kurgan, hco, formalised,
# Nearest to were: are, was, had, have, been, internalism, be, although,
# Nearest to and: or, but, pickard, including, while, where, popped, guyana,
# Nearest to are: were, is, have, include, these, be, including, although,
# Nearest to most: more, some, many, pupil, tilting, nage, use, all,
# Nearest to eight: nine, seven, six, five, four, three, zero, one,
# Nearest to often: usually, sometimes, generally, commonly, also, now, still, largely,
# Nearest to to: would, diplomas, must, rejoining, parlement, ethology, towards, cannot,
# Nearest to as: keel, migratory, lcd, massive, wta, maneuvers, rommel, dias,
# Nearest to s: john, iberia, leni, situs, nizam, bill, his, pastry,
# Nearest to people: others, men, children, those, cort, karlheinz, cbc, revolution,
# Nearest to not: still, usually, now, waitress, boredom, never, nato, deprived,
# Average loss at step 52000: 3.325375
# Average loss at step 54000: 3.425111
# Average loss at step 56000: 3.395471
# Average loss at step 58000: 3.438152
# Average loss at step 60000: 3.456589
# Nearest to war: poignant, muay, wars, welwyn, pipelined, silo, oghuz, dymaxion,
# Nearest to only: not, moa, theodora, still, easily, spratly, grasping, acquittal,
# Nearest to by: through, mahesh, being, multivibrator, with, naka, was, suckling,
# Nearest to on: upon, through, in, laughing, prescott, hodder, hajj, slays,
# Nearest to that: which, however, what, this, often, because, gera, amharic,
# Nearest to were: are, was, have, had, those, been, internalism, including,
# Nearest to and: or, but, including, flourish, while, which, vhf, gilliam,
# Nearest to are: were, is, have, include, although, be, was, these,
# Nearest to most: more, many, some, use, less, geology, filters, among,
# Nearest to eight: six, seven, nine, four, five, three, one, zero,
# Nearest to often: sometimes, usually, commonly, generally, still, also, now, widely,
# Nearest to to: will, would, should, parlement, towards, must, can, in,
# Nearest to as: completeness, massive, cyrillic, migratory, occult, including, ret, rommel,
# Nearest to s: leni, fixture, his, monsignor, missions, goncourt, ordinations, situs,
# Nearest to people: men, children, others, women, karlheinz, countries, today, cort,
# Nearest to not: still, usually, never, always, only, generally, often, boredom,
# Average loss at step 62000: 3.434825
# Average loss at step 64000: 3.397848
# Average loss at step 66000: 3.398387
# Average loss at step 68000: 3.411697
# Average loss at step 70000: 3.324739
# Nearest to war: oghuz, welwyn, wars, poignant, totals, rocky, fredrik, symphonie,
# Nearest to only: moa, easily, still, grasping, within, spratly, not, theodora,
# Nearest to by: through, mahesh, multivibrator, suckling, tribal, senator, homonyms, apcs,
# Nearest to on: upon, in, through, around, thessalonica, hajj, prescott, from,
# Nearest to that: which, however, what, but, gera, expires, kurgan, retrospective,
# Nearest to were: are, was, have, had, while, internalism, although, been,
# Nearest to and: or, including, but, especially, although, while, however, in,
# Nearest to are: were, is, have, include, juggling, although, be, abrams,
# Nearest to most: more, many, some, pupil, among, several, less, throughout,
# Nearest to eight: six, nine, seven, four, five, three, one, zero,
# Nearest to often: usually, sometimes, commonly, generally, typically, now, widely, still,
# Nearest to to: rejoining, beretta, novelization, will, towards, peculiar, parlement, ethology,
# Nearest to as: reflux, massive, reuse, graham, realised, including, migratory, maneuvers,
# Nearest to s: ansible, fandango, decibel, schechter, asymmetric, isbn, grouse, tags,
# Nearest to people: men, women, children, those, writers, others, students, players,
# Nearest to not: usually, still, generally, never, now, always, also, waitress,
# Average loss at step 72000: 3.376502
# Average loss at step 74000: 3.296577
# Average loss at step 76000: 3.389158
# Average loss at step 78000: 3.379475
# Average loss at step 80000: 3.360456
# Nearest to war: welwyn, wars, oghuz, colombo, totals, symphonie, rocky, fredrik,
# Nearest to only: theodora, moa, easily, within, still, gomoku, grasping, until,
# Nearest to by: with, after, through, gagarin, during, mahesh, including, and,
# Nearest to on: upon, in, thessalonica, about, from, through, slipknot, around,
# Nearest to that: which, what, however, but, kurgan, this, gera, actually,
# Nearest to were: are, was, had, have, internalism, being, these, be,
# Nearest to and: or, but, including, while, with, however, s, although,
# Nearest to are: were, have, include, be, while, these, is, although,
# Nearest to most: more, many, pupil, some, less, several, use, checkerboard,
# Nearest to eight: seven, nine, six, five, four, three, zero, two,
# Nearest to often: usually, sometimes, commonly, generally, typically, widely, frequently, largely,
# Nearest to to: towards, sprang, rejoining, beretta, nk, shall, faltering, could,
# Nearest to as: migratory, ifv, annulled, karelian, like, bor, dias, shaivism,
# Nearest to s: leni, and, whose, his, american, riel, situs, her,
# Nearest to people: men, others, women, children, students, players, individuals, those,
# Nearest to not: still, never, generally, usually, boredom, waitress, now, obviously,
# Average loss at step 82000: 3.354809
# Average loss at step 84000: 3.413392
# Average loss at step 86000: 3.344537
# Average loss at step 88000: 3.190537
# Average loss at step 90000: 3.348791
# Nearest to war: welwyn, symphonie, during, totals, wars, oghuz, ubangi, rocky,
# Nearest to only: moa, gomoku, grasping, basis, easily, normally, within, until,
# Nearest to by: through, hoppers, scientifically, mahesh, from, without, beneath, pneumoniae,
# Nearest to on: upon, in, through, within, around, newcomers, powerbook, thessalonica,
# Nearest to that: which, what, however, but, often, generally, also, samael,
# Nearest to were: are, have, those, had, was, internalism, been, although,
# Nearest to and: or, including, although, while, but, stricken, like, where,
# Nearest to are: were, is, have, include, although, be, while, avenida,
# Nearest to most: more, many, less, pupil, use, some, among, checkerboard,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to often: usually, sometimes, commonly, generally, typically, now, also, frequently,
# Nearest to to: nk, could, rejoining, cannot, would, should, can, will,
# Nearest to as: migratory, keel, maneuvers, cowan, like, when, ifv, endorse,
# Nearest to s: whose, situs, aesthetically, adrian, tracey, vertigo, gholas, winnings,
# Nearest to people: men, individuals, citizens, children, those, women, others, students,
# Nearest to not: still, now, usually, never, t, always, generally, typically,
# Average loss at step 92000: 3.311454
# Average loss at step 94000: 3.366327
# Average loss at step 96000: 3.356582
# Average loss at step 98000: 3.325376
# Average loss at step 100000: 3.328025
# Nearest to war: welwyn, symphonie, totals, oghuz, battle, wars, rocky, ubangi,
# Nearest to only: until, grasping, moa, normally, last, hathaway, novelties, wtro,
# Nearest to by: through, with, using, from, pneumoniae, during, homonyms, hoppers,
# Nearest to on: upon, thessalonica, in, through, slipknot, hajj, around, syrups,
# Nearest to that: which, however, what, but, kurgan, samael, gera, fawkes,
# Nearest to were: are, those, have, was, include, these, avenida, had,
# Nearest to and: or, but, including, although, s, icsu, while, pickard,
# Nearest to are: were, have, include, is, those, be, these, internalism,
# Nearest to most: more, many, some, less, especially, use, pupil, checkerboard,
# Nearest to eight: six, nine, seven, four, five, three, zero, two,
# Nearest to often: usually, sometimes, generally, commonly, typically, frequently, also, still,
# Nearest to to: will, would, shall, rejoining, might, must, beretta, could,
# Nearest to as: migratory, roses, obstructed, reginae, maneuvers, until, pozna, when,
# Nearest to s: whose, monsignor, isbn, and, wrote, yaw, robert, schechter,
# Nearest to people: men, individuals, those, citizens, children, countries, others, women,
# Nearest to not: still, now, never, usually, generally, t, always, waitress,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
# Out:
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
